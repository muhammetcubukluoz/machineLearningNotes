# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv("10-diamonds.csv")

# %%
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53940 rows x 11 columns]

# %%
data.shape
# Out:
# (53940, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
data = data.drop("Unnamed: 0", axis=1)

# %%
data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
data.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
data.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
data[data["x"] == 0]
# Out:
#        carat        cut color clarity  depth  table  price    x     y    z
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.0  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.0  0.00  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.0  0.00  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.0  0.00  0.0
# 26243   1.20    Premium     D    VVS1   62.1   59.0  15686  0.0  0.00  0.0
# 27429   2.25    Premium     H     SI2   62.8   59.0  18034  0.0  0.00  0.0
# 49556   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.00  0.0
# 49557   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.00  0.0

# %%
data[data["y"] == 0]
# Out:
#        carat        cut color clarity  depth  table  price    x    y    z
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.0  0.0  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.0  0.0  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.0  0.0  0.0
# 26243   1.20    Premium     D    VVS1   62.1   59.0  15686  0.0  0.0  0.0
# 27429   2.25    Premium     H     SI2   62.8   59.0  18034  0.0  0.0  0.0
# 49556   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.0  0.0
# 49557   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.0  0.0

# %%
data[data["z"] == 0]
# Out:
#        carat        cut color clarity  depth  table  price     x     y    z
# 2207    1.00    Premium     G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 2314    1.01    Premium     H      I1   58.1   59.0   3167  6.66  6.60  0.0
# 4791    1.10    Premium     G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 5471    1.01    Premium     F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 10167   1.50       Good     G      I1   64.0   61.0   4731  7.15  7.04  0.0
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.00  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.00  0.00  0.0
# 13601   1.15      Ideal     G     VS2   59.2   56.0   5564  6.88  6.83  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.00  0.00  0.0
# 24394   2.18    Premium     H     SI2   59.4   61.0  12631  8.49  8.45  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.00  0.00  0.0
# 26123   2.25    Premium     I     SI1   61.3   58.0  15397  8.52  8.42  0.0
# 26243   1.20    Premium     D    VVS1   62.1   59.0  15686  0.00  0.00  0.0
# 27112   2.20    Premium     H     SI1   61.2   59.0  17265  8.42  8.37  0.0
# 27429   2.25    Premium     H     SI2   62.8   59.0  18034  0.00  0.00  0.0
# 27503   2.02    Premium     H     VS2   62.7   53.0  18207  8.02  7.95  0.0
# 27739   2.80       Good     G     SI2   63.8   58.0  18788  8.90  8.85  0.0
# 49556   0.71       Good     F     SI2   64.1   60.0   2130  0.00  0.00  0.0
# 49557   0.71       Good     F     SI2   64.1   60.0   2130  0.00  0.00  0.0
# 51506   1.12    Premium     G      I1   60.4   59.0   2383  6.71  6.67  0.0

# %%
len(data[data["x"] == 0]), len(data[data["y"] == 0]), len(data[data["z"] == 0])
# Out:
# (8, 7, 20)

# %%
data = data.drop(data[data["z"] == 0].index)
data = data.drop(data[data["y"] == 0].index)
data = data.drop(data[data["x"] == 0].index)

# %%
data.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53920.000000  53920.000000  53920.000000  53920.000000  53920.000000
# mean       0.797698     61.749514     57.456834   3930.993231      5.731627
# std        0.473795      1.432331      2.234064   3987.280446      1.119423
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5323.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53920.000000  53920.000000
# mean       5.734887      3.540046
# std        1.140126      0.702530
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
data.shape
# Out:
# (53920, 10)

# %%
sns.pairplot(data)
plt.show()

# %%
sns.scatterplot(x=data["x"], y=data["price"])
plt.show()

# %%
sns.scatterplot(x=data["y"], y=data["price"])
plt.show()

# %%
sns.scatterplot(x=data["z"], y=data["price"])
plt.show()

# %%
sns.scatterplot(x=data["table"], y=data["price"])
plt.show()

# %%
sns.scatterplot(x=data["depth"], y=data["price"])
plt.show()

# %%
len(data[(data["depth"]<75) & (data["depth"]>45)])
# Out:
# 53914

# %%
len(data)
# Out:
# 53920

# %%
len(data[(data["table"]<75) & (data["table"]>40)])
# Out:
# 53917

# %%
len(data[(data["z"]<30) & (data["z"]>2)])
# Out:
# 53916

# %%
len(data[(data["y"]<20)])
# Out:
# 53918

# %%
data = data[(data["depth"]<75) & (data["depth"]>45)]
data = data[(data["table"]<75) & (data["table"]>40)]
data = data[(data["z"]<30) & (data["z"]>2)]
data = data[(data["y"]<20)]

# %%
data.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53905.000000  53905.000000  53905.000000  53905.000000  53905.000000
# mean       0.797628     61.749545     57.455205   3930.643799      5.731476
# std        0.473774      1.419739      2.222825   3987.264881      1.119402
# min        0.200000     50.800000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5322.000000      6.540000
# max        5.010000     73.600000     73.000000  18823.000000     10.740000
#
#                   y             z
# count  53905.000000  53905.000000
# mean       5.733313      3.539443
# std        1.111267      0.691446
# min        3.680000      2.060000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       10.540000      6.980000

# %%
sns.scatterplot(x=data["y"], y=data["price"])
plt.show()

# %%
sns.scatterplot(x=data["z"], y=data["price"])
plt.show()

# %%
data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
data["cut"].value_counts()
# Out:
# cut
# Ideal        21543
# Premium      13779
# Very Good    12080
# Good          4902
# Fair          1601
# Name: count, dtype: int64

# %%
data["color"].value_counts()
# Out:
# color
# G    11281
# E     9792
# F     9535
# H     8296
# D     6774
# I     5420
# J     2807
# Name: count, dtype: int64

# %%
data["clarity"].value_counts()
# Out:
# clarity
# SI1     13058
# VS2     12250
# SI2      9183
# VS1      8167
# VVS2     5066
# VVS1     3654
# IF       1790
# I1        737
# Name: count, dtype: int64

# %%
#before encoding these, i will split this into train-test to avoid data leakage

# %%
X = data.drop("price", axis=1)
y = data["price"]

# %%
X.head()
# Out:
#    carat      cut color clarity  depth  table     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  4.34  4.35  2.75

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=15)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
for col in ["cut", "color", "clarity"]:
    X_train[col] = label_encoder.fit_transform(X_train[col])
    X_test[col] = label_encoder.transform(X_test[col])

# %%
X_train.head()
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z
# 15200   1.15    2      4        2   62.4   54.0  6.71  6.76  4.20
# 14632   1.11    3      1        2   61.3   58.0  6.66  6.61  4.07
# 19151   1.21    1      2        5   63.7   58.0  6.67  6.71  4.26
# 29299   0.30    2      5        5   61.5   58.0  4.28  4.31  2.64
# 9983    1.00    4      2        2   63.1   57.0  6.37  6.33  4.01

# %%
X_train["cut"].value_counts()
# Out:
# cut
# 2    16164
# 3    10371
# 4     9018
# 1     3684
# 0     1191
# Name: count, dtype: int64

# %%
X_test["cut"].value_counts()
# Out:
# cut
# 2    5379
# 3    3408
# 4    3062
# 1    1218
# 0     410
# Name: count, dtype: int64

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40428 entries, 15200 to 7630
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    40428 non-null  float64
#  1   cut      40428 non-null  int64
#  2   color    40428 non-null  int64
#  3   clarity  40428 non-null  int64
#  4   depth    40428 non-null  float64
#  5   table    40428 non-null  float64
#  6   x        40428 non-null  float64
#  7   y        40428 non-null  float64
#  8   z        40428 non-null  float64
# dtypes: float64(6), int64(3)
# memory usage: 3.1 MB

# %%
X_train.describe()
# Out:
#               carat           cut         color       clarity         depth  \
# count  40428.000000  40428.000000  40428.000000  40428.000000  40428.000000
# mean       0.796222      2.552612      2.596567      3.837761     61.753070
# std        0.474151      1.025862      1.702791      1.722900      1.412191
# min        0.200000      0.000000      0.000000      0.000000     51.000000
# 25%        0.400000      2.000000      1.000000      2.000000     61.100000
# 50%        0.700000      2.000000      3.000000      4.000000     61.800000
# 75%        1.040000      3.000000      4.000000      5.000000     62.500000
# max        5.010000      4.000000      6.000000      7.000000     73.600000
#
#               table             x             y             z
# count  40428.000000  40428.000000  40428.000000  40428.000000
# mean      57.457099      5.727558      5.729274      3.537217
# std        2.222914      1.119944      1.111769      0.692054
# min       43.000000      3.730000      3.680000      2.240000
# 25%       56.000000      4.710000      4.720000      2.910000
# 50%       57.000000      5.690000      5.700000      3.520000
# 75%       59.000000      6.540000      6.530000      4.030000
# max       73.000000     10.740000     10.540000      6.980000

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
linear = LinearRegression()
linear.fit(X_train_scaled, y_train)
y_pred = linear.predict(X_test_scaled)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-Squared:", r2)

plt.scatter(y_test, y_pred)
plt.show()
# Out:
# Mean Absolute Error: 867.7716773299012
# Mean Squared Error: 1849507.2709594548
# R-Squared: 0.8848902306205187

# %%
from sklearn.svm import SVR

# %%
svr = SVR()
svr.fit(X_train_scaled, y_train)
y_pred = svr.predict(X_test_scaled)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-Squared:", r2)

plt.scatter(y_test, y_pred)
plt.show()
# Out:
# Mean Absolute Error: 1397.853335232954
# Mean Squared Error: 8151981.896752332
# R-Squared: 0.4926363519327641

# %%
#hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html
param_grid = {
    "kernel": ["linear", "rbf"],
    "gamma" : [1, 0.1, 0.001],
    "C" : [0.1, 1, 10, 100, 1000]
}

# %%
grid = GridSearchCV(estimator=SVR(), param_grid=param_grid, n_jobs=-1, verbose=3)

# %%
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100, 1000], 'gamma': [1, 0.1, 0.001],
#                          'kernel': ['linear', 'rbf']},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
y_pred = grid.predict(X_test_scaled)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-Squared:", r2)

plt.scatter(y_test, y_pred)
plt.show()
# Out:
# Mean Absolute Error: 480.6663510891458
# Mean Squared Error: 874992.2341646876
# R-Squared: 0.9455421690603658
